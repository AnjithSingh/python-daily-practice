# %%
import requests
from bs4 import BeautifulSoup

# %%
with open('scrap.html', 'r') as html_file:
    content = html_file.read()
print(content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Practice Bookstore</title>
#     <style>
#         body { font-family: sans-serif; padding: 20px; }
#         .book { border: 1px solid #ccc; padding: 10px; margin-bottom: 10px; }
#         .title { color: #333; font-size: 18px; font-weight: bold; }
#         .price { color: green; font-weight: bold; }
#         .stock { color: blue; font-size: 0.9em; }
#     </style>
# </head>
# <body>
#
#     <h1 id="main-heading">Best Selling Python Books</h1>
#     <p>We found <span id="total-books">3</span> books for you.</p>
#
#     <div class="book-container">
#
#         <article class="book">
#             <h2 class="title">
#                 <a href="catalogue/python-crash-course.html">Python Crash Course</a>
#             </h2>
#             <p class="author">By: <span class="author-name">Eric Matthes</span></p>
#             <p class="price">$27.99</p>
# ...

# %%
with open('scrap.html', 'r') as html_file:
    content = html_file.read()

    soup = BeautifulSoup(content , 'lxml')
    print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Practice Bookstore</title>
# <style>
#         body { font-family: sans-serif; padding: 20px; }
#         .book { border: 1px solid #ccc; padding: 10px; margin-bottom: 10px; }
#         .title { color: #333; font-size: 18px; font-weight: bold; }
#         .price { color: green; font-weight: bold; }
#         .stock { color: blue; font-size: 0.9em; }
#     </style>
# </head>
# <body>
# <h1 id="main-heading">Best Selling Python Books</h1>
# <p>We found <span id="total-books">3</span> books for you.</p>
# <div class="book-container">
# <article class="book">
# <h2 class="title">
# <a href="catalogue/python-crash-course.html">Python Crash Course</a>
# </h2>
# <p class="author">By: <span class="author-name">Eric Matthes</span></p>
# <p class="price">$27.99</p>
# <div class="rating" data-rating="5">*****</div>
# <p class="stock">In Stock</p>
# </article>
# <article class="book">
# ...

# %%
with open('scrap.html', 'r') as html_file:
    content = html_file.read()

    soup = BeautifulSoup(content , 'lxml')
    
    tags = soup.find_all('h2') # Sabhi h2 ko show krta hai
    tags2 = soup.find('h2') # PAHLE JO BHI H2 MILEGA USKO SHOW KRTA HAI
    print(tags)
    print('aaaa/n')
    print(tags2)
# Out:
# [<h2 class="title">
# <a href="catalogue/python-crash-course.html">Python Crash Course</a>
# </h2>, <h2 class="title">
# <a href="catalogue/automate-the-boring-stuff.html">Automate the Boring Stuff</a>
# </h2>, <h2 class="title">
# <a href="catalogue/learning-python.html">Learning Python</a>
# </h2>]
# aaaa/n
# <h2 class="title">
# <a href="catalogue/python-crash-course.html">Python Crash Course</a>
# </h2>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# catalogue/python-crash-course.html
# catalogue/automate-the-boring-stuff.html
# catalogue/learning-python.html
# mailto:support@books.com

# %%
for titles in soup.find_all('title'):
    print(titles.text)
# Out:
# Practice Bookstore

# %%
for headings in soup.find_all('h1'):
    print(headings.text)
# Out:
# Best Selling Python Books

# %%
for subheading in soup.find_all('h2'):
    print(subheading.text)
# Out:
# Python Crash Course
#
#
# Automate the Boring Stuff
#
#
# Learning Python
