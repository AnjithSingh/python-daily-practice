# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (1.28.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.11.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.26.4)
# Collecting packaging<24,>=16.8 (from streamlit)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (10.1.0)
# Collecting protobuf<5,>=3.20 (from streamlit)
#   Downloading protobuf-4.25.9-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (16.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.35.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\anshu\appdata\roaming\python\python310\site-packages (from streamlit) (6.4)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.0.0)
# Requirement already satisfied: jinja2 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (4.22.0)
# Requirement already satisfied: toolz in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anshu\appdata\roaming\python\python310\site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\anshu\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
# Downloading protobuf-4.25.9-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: protobuf, packaging
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 6.33.5
#
#     Uninstalling protobuf-6.33.5:
#
#       Successfully uninstalled protobuf-6.33.5
#
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#   Attempting uninstall: packaging
#    ---------------------------------------- 0/2 [protobuf]
#     Found existing installation: packaging 24.2
#    ---------------------------------------- 0/2 [protobuf]
#     Uninstalling packaging-24.2:
#    ---------------------------------------- 0/2 [protobuf]
#       Successfully uninstalled packaging-24.2
#    ---------------------------------------- 0/2 [protobuf]
#    -------------------- ------------------- 1/2 [packaging]
#    -------------------- ------------------- 1/2 [packaging]
#    ---------------------------------------- 2/2 [packaging]
#
# Successfully installed packaging-23.2 protobuf-4.25.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# accelerate 0.33.0 requires huggingface-hub>=0.21.0, but you have huggingface-hub 0.17.3 which is incompatible.
# build 1.4.0 requires packaging>=24.0, but you have packaging 23.2 which is incompatible.
# datasets 2.21.0 requires huggingface-hub>=0.21.2, but you have huggingface-hub 0.17.3 which is incompatible.
# datasets 2.21.0 requires requests>=2.32.2, but you have requests 2.31.0 which is incompatible.
# opentelemetry-proto 1.40.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.

# %%
import streamlit as st 
import pandas as pd
import numpy as np 


# Title 

st.title("Hello Streamlit")
# Out:
# 2026-04-16 07:12:25.675
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\anshu\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
## Display a simple Text

st.write("This is simple text")

df = pd.DataFrame({
    'First column': [1,2,3,4],
    'second column' : [10,20,30,40]  
})

# %%
#display the dataframe

st.write("Here is my DataFrame")
st.write(df)

# %%
#Create a line chart

chart_data =  pd.DataFrame(
    np.random.randn(20,3), columns=['a','b','c']
)
st.line_chart(chart_data)
# Out:
# DeltaGenerator()
